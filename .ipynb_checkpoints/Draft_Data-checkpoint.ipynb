# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
filepath = "NBA_Draft_1980_2017.tsv"
Data = pd.read_csv(filepath, sep = '\t')
Data
# Out:
#       year  round  pick              player position         school
# 0     1980      1   1.0  Carroll, Joe Barry      F/C         Purdue
# 1     1980      1   2.0   Griffith, Darrell        G     Louisville
# 2     1980      1   3.0       McHale, Kevin      F/C      Minnesota
# 3     1980      1   4.0      Ransey, Kelvin        G     Ohio State
# 4     1980      1   5.0          Ray, James        F   Jacksonville
# ...    ...    ...   ...                 ...      ...            ...
# 2162  2018      2  56.0         Jacob Evans       SF     Cincinnati
# 2163  2018      2  57.0        Jevon Carter       PG  West Virginia
# 2164  2018      2  58.0      Borisa Simanic    SF/PF         Serbia
# 2165  2018      2  59.0       Bonzie Colson    SF/PF     Notre Dame
# 2166  2018      2  60.0    Kendall Stephens    SG/SF         Nevada
#
# [2167 rows x 6 columns]

# %%
Data.dtypes
# Out:
# year          int64
# round         int64
# pick        float64
# player       object
# position     object
# school       object
# dtype: object

# %%
Data = Data.dropna()
Data
# Out:
#       year  round  pick              player position         school
# 0     1980      1   1.0  Carroll, Joe Barry      F/C         Purdue
# 1     1980      1   2.0   Griffith, Darrell        G     Louisville
# 2     1980      1   3.0       McHale, Kevin      F/C      Minnesota
# 3     1980      1   4.0      Ransey, Kelvin        G     Ohio State
# 4     1980      1   5.0          Ray, James        F   Jacksonville
# ...    ...    ...   ...                 ...      ...            ...
# 2162  2018      2  56.0         Jacob Evans       SF     Cincinnati
# 2163  2018      2  57.0        Jevon Carter       PG  West Virginia
# 2164  2018      2  58.0      Borisa Simanic    SF/PF         Serbia
# 2165  2018      2  59.0       Bonzie Colson    SF/PF     Notre Dame
# 2166  2018      2  60.0    Kendall Stephens    SG/SF         Nevada
#
# [2166 rows x 6 columns]

# %%
filepath = "NBADraftData.csv"
Data = pd.read_csv(filepath)

# %%
# Data['last name'], Data['first name'] = Data['player'].str.split(', ', 1).str
# Data['last name'], Data['first name'] = Data['player'].str.split(' ', 1).str
D2018 = Data.loc[Data['year'] == 2018]
D2018['first name'], D2018['last name'] = D2018['player'].str.split(' ', 1).str
D2018
# Out:
# C:\Users\lukee\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   after removing the cwd from sys.path.
# C:\Users\lukee\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       year  round  pick               player position            school  \
# 2106  2018      1     1        DeAndre Ayton        C           Arizona
# 2107  2018      1     2    Jaren Jackson Jr.       PF      Michigan St.
# 2108  2018      1     3       Michael Porter       SF          Missouri
# 2109  2018      1     4        Marvin Bagley       PF              Duke
# 2110  2018      1     5          Luka Doncic    SG/SF          Slovenia
# 2111  2018      1     6       Wendell Carter     PF/C              Duke
# 2112  2018      1     7           Trae Young       PG          Oklahoma
# 2113  2018      1     8        Mohamed Bamba        C             Texas
# 2114  2018      1     9        Collin Sexton       PG           Alabama
# 2115  2018      1    10           Kevin Knox    SF/PF          Kentucky
# 2116  2018      1    11        Mikal Bridges    SG/SF         Villanova
# 2117  2018      1    12        Miles Bridges    SF/PF      Michigan St.
# 2107     Jackson Jr.       Jaren
# 2108          Porter     Michael
# 2109          Bagley      Marvin
# 2110          Doncic        Luka
# 2111          Carter     Wendell
# 2112           Young        Trae
# 2113           Bamba     Mohamed
# 2114          Sexton      Collin
# 2115            Knox       Kevin
# 2116         Bridges       Mikal
# 2117         Bridges       Miles
# 2118  Gilgeous-Al...        Shai
# 2119        Williams      Robert
# 2120       Trent Jr.        Gary
# 2121          Walker      Lonnie
# 2122            Musa      Dzanan
# 2123          Diallo     Hamidou
# 2124          Thomas       Khyri
# 2125        Robinson    Mitchell
# 2126           Duval      Trevon
# 2127           Allen     Grayson
# 2128            Metu    Chimezie
# 2129          Shamet      Landry
# 2130           McCoy     Brandon
# 2131           Brown        Troy
# 2132       Yurtseven        Omer
# 2133           Wiley      Austin
# 2134            Carr        Tony
# 2135          Wagner      Moritz
# 2136          Kurucs     Rodions
# 2137           Brown       Bruce
# 2138           Roach      Kerwin
# 2139           Bonga       Isaac
# 2140          Franks      Robert
# 2141       Hutchison    Chandler
# 2142        Williams     Kenrich
# 2143      Bates-Diop       Keita
# 2144         Johnson       Alize
# 2145         Holiday       Aaron
# 2146           Mykha  Sviatoslav
# 2147           Adams      Jaylen
# 2148          Hervey       Kevin
# 2149           Trier     Allonzo
# 2150           Evans      Keenan
# 2151          Milton       Shake
# 2152         Bitadze        Goga
# 2153         Brunson       Jalen
# 2154          Wilder      Thomas
# 2155          Alkins       Rawle
# 2156          Hudson       Jalen
# 2157          Graham     Devonte
# 2158         Kulboka    Arnoldas
# 2159         Frazier      Melvin
# 2160           Berry        Joel
# 2161           Evans       Jacob
# 2162          Carter       Jevon
# 2163         Simanic      Borisa
# 2164          Colson      Bonzie
# 2165        Stephens     Kendall

# %%
# Data = Data[Data["year"] != 2018]
# df.append(df2, ignore_index=True)
Data2 = Data.append(D2018)
Data2
# Out:
#       year  round  pick              player position         school last name  \
# 0     1980      1     1  Carroll, Joe Barry      F/C         Purdue   Carroll
# 1     1980      1     2   Griffith, Darrell        G     Louisville  Griffith
# 2     1980      1     3       McHale, Kevin      F/C      Minnesota    McHale
# 3     1980      1     4      Ransey, Kelvin        G     Ohio State    Ransey
# 4     1980      1     5          Ray, James        F   Jacksonville       Ray
# ...    ...    ...   ...                 ...      ...            ...       ...
# 2161  2018      2    56         Jacob Evans       SF     Cincinnati     Evans
# 2162  2018      2    57        Jevon Carter       PG  West Virginia    Carter
# 2163  2018      2    58      Borisa Simanic    SF/PF         Serbia   Simanic
# 2164  2018      2    59       Bonzie Colson    SF/PF     Notre Dame    Colson
# 2165  2018      2    60    Kendall Stephens    SG/SF         Nevada  Stephens
#
#      first name
# 0     Joe Barry
# 1       Darrell
# 2         Kevin
# 3        Kelvin
# 4         James
# ...         ...
# 2161      Jacob
# 2162      Jevon
# 2163     Borisa
# 2164     Bonzie
# 2165    Kendall
#
# [2166 rows x 8 columns]

# %%
Data2.to_csv("NBADraftData2.csv", index = False)
