# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# adjusting for file type (tsv to csv)
filepath = "NBA_Draft_1980_2017.tsv"
Data = pd.read_csv(filepath, sep = '\t')
Data
# Out:
#       year  round  pick              player position         school
# 0     1980      1   1.0  Carroll, Joe Barry      F/C         Purdue
# 1     1980      1   2.0   Griffith, Darrell        G     Louisville
# 2     1980      1   3.0       McHale, Kevin      F/C      Minnesota
# 3     1980      1   4.0      Ransey, Kelvin        G     Ohio State
# 4     1980      1   5.0          Ray, James        F   Jacksonville
# ...    ...    ...   ...                 ...      ...            ...
# 2162  2018      2  56.0         Jacob Evans       SF     Cincinnati
# 2163  2018      2  57.0        Jevon Carter       PG  West Virginia
# 2164  2018      2  58.0      Borisa Simanic    SF/PF         Serbia
# 2165  2018      2  59.0       Bonzie Colson    SF/PF     Notre Dame
# 2166  2018      2  60.0    Kendall Stephens    SG/SF         Nevada
#
# [2167 rows x 6 columns]

# %%
Data.dtypes
# Out:
# year          int64
# round         int64
# pick        float64
# player       object
# position     object
# school       object
# dtype: object

# %%
Data = Data.dropna()
Data
# Out:
#       year  round  pick              player position         school
# 0     1980      1   1.0  Carroll, Joe Barry      F/C         Purdue
# 1     1980      1   2.0   Griffith, Darrell        G     Louisville
# 2     1980      1   3.0       McHale, Kevin      F/C      Minnesota
# 3     1980      1   4.0      Ransey, Kelvin        G     Ohio State
# 4     1980      1   5.0          Ray, James        F   Jacksonville
# ...    ...    ...   ...                 ...      ...            ...
# 2162  2018      2  56.0         Jacob Evans       SF     Cincinnati
# 2163  2018      2  57.0        Jevon Carter       PG  West Virginia
# 2164  2018      2  58.0      Borisa Simanic    SF/PF         Serbia
# 2165  2018      2  59.0       Bonzie Colson    SF/PF     Notre Dame
# 2166  2018      2  60.0    Kendall Stephens    SG/SF         Nevada
#
# [2166 rows x 6 columns]

# %%
filepath = "NBADraftData.csv"
Data = pd.read_csv(filepath)

# %%
# Swap Last name and first name on most years and reorient for names for consistancy. 
Data['last name'], Data['first name'] = Data['player'].str.split(', ', 1).str
D2018 = Data.loc[Data['year'] == 2018]
D1992 = Data.loc[Data['year'] == 1992]
D1990 = Data.loc[Data['year'] == 1990]
D1989 = Data.loc[Data['year'] == 1989]
D2018['first name'], D2018['last name'] = D2018['player'].str.split(' ', 1).str
D1992['first name'], D1992['last name'] = D1992['player'].str.split(' ', 1).str
D1989['first name'], D1989['last name'] = D1989['player'].str.split(' ', 1).str
D1990['first name'], D1990['last name'] = D1990['player'].str.split(' ', 1).str
D1989
# Out:
# C:\Users\lukee\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.
# C:\Users\lukee\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#
# C:\Users\lukee\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lukee\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   import sys
# ...

# %%
# drop rows with incorrect formatting and replace with adjusted format
Data = Data[Data["year"] != 2018]
Data = Data[Data["year"] != 1992]
Data = Data[Data["year"] != 1989]
Data = Data[Data["year"] != 1990]
# df.append(df2, ignore_index=True)
Data = Data.append(D2018)
Data = Data.append(D1992)
Data = Data.append(D1989)
Data = Data.append(D1990)
Data
# Out:
#      year  round  pick              player position          school  \
# 0    1980      1     1  Carroll, Joe Barry      F/C          Purdue
# 1    1980      1     2   Griffith, Darrell        G      Louisville
# 2    1980      1     3       McHale, Kevin      F/C       Minnesota
# 3    1980      1     4      Ransey, Kelvin        G      Ohio State
# 4    1980      1     5          Ray, James        F    Jacksonville
# ..    ...    ...   ...                 ...      ...             ...
# 525  1990      2    50         Miloš Babić        C  Tennessee Tech
# 526  1990      2    51          Tony Smith        G       Marquette
# 527  1990      2    52     Stefano Rusconi     PF/C  Ranger Varese
# 528  1990      2    53  Abdul Shamsid-Deen        C      Providence
# 529  1990      2    54        Sean Higgins      G/F        Michigan
#
#         last name first name
# 0         Carroll  Joe Barry
# 1        Griffith    Darrell
# 2          McHale      Kevin
# 3          Ransey     Kelvin
# ...

# %%
# abandoned attempt to streamline changes through For loop
# if Data2['player'].str.contains(',').all() == True:
#     Data2['last name'], Data2['first name'] = Data2['player'].str.split(', ', 1).str
# else:
#     Data2['first name'], Data2['last name'] = Data2['player'].str.split(' ').str
# Out:
# C:\Users\lukee\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-c7b3c605ef7a> in <module>
#       2     Data2['last name'], Data2['first name'] = Data2['player'].str.split(', ', 1).str
#       3 else:
# ----> 4     Data2['first name'], Data2['last name'] = Data2['player'].str.split(' ').str
#
# ValueError: too many values to unpack (expected 2)

# %%
# Data["player"] = Data["first name"] + " " + Data["last name"]
Data.loc[Data['year'] == 2001]
# Out:
#       year  round  pick                 player position  \
# 1093  2001      1     1            Kwame Brown        C
# 1094  2001      1     2         Tyson Chandler        C
# 1095  2001      1     3              Pau Gasol     PF/C
# 1096  2001      1     4             Eddy Curry        C
# 1097  2001      1     5       Jason Richardson       SG
# 1098  2001      1     6          Shane Battier       SF
# 1099  2001      1     7          Eddie Griffin       PF
# 1100  2001      1     8          DeSagana Diop        C
# 1101  2001      1     9           Rodney White    SF/PF
# 1102  2001      1    10            Joe Johnson       SG
# 1103  2001      1    11          Kedrick Brown       SF
# 1104  2001      1    12    Vladimir Radmanović       PF
# 1105  2001      1    13      Richard Jefferson       SF
# 1106  2001      1    14            Troy Murphy       PF
# 1107  2001      1    15          Steven Hunter        C
# 1108  2001      1    16            Kirk Haston       PF
# ...

# %%
# load adjustments into new csv
Data3.to_csv("NBADraftData2.csv", index = False)

# %%
# Below are adjustments meant to clean issues with encoding, draft pick forfeits, and other rows with null values
# Note that cells may have been changed just slightly to address different issues instead of creating new cells
filepath = "NBADraftData2.csv"
Data4 = pd.read_csv(filepath, encoding = 'utf-8')
Data4
# Out:
#       year  round  pick              player position          school  \
# 0     1980      1     1   Joe Barry Carroll      F/C          Purdue
# 1     1980      1     2    Darrell Griffith        G      Louisville
# 2     1980      1     3        Kevin McHale      F/C       Minnesota
# 3     1980      1     4       Kelvin Ransey        G      Ohio State
# 4     1980      1     5           James Ray        F    Jacksonville
# ...    ...    ...   ...                 ...      ...             ...
# 2153  1990      2    50       MiloÅ¡ BabiÄ‡        C  Tennessee Tech
# 2154  1990      2    51          Tony Smith        G       Marquette
# 2155  1990      2    52     Stefano Rusconi     PF/C   Ranger Varese
# 2156  1990      2    53  Abdul Shamsid-Deen        C      Providence
# 2157  1990      2    54        Sean Higgins      G/F        Michigan
#
#          last name first name
# 0          Carroll  Joe Barry
# 1         Griffith    Darrell
# 2           McHale      Kevin
# ...

# %%
Data3 = Data3[Data3["last name"] != "Forfeited pick"]

# %%
Data3 = Data3.dropna(how='any', axis=0)
Data3
# Out:
#       year  round  pick              player position          school  \
# 0     1980      1     1   Joe Barry Carroll      F/C          Purdue
# 1     1980      1     2    Darrell Griffith        G      Louisville
# 2     1980      1     3        Kevin McHale      F/C       Minnesota
# 3     1980      1     4       Kelvin Ransey        G      Ohio State
# 4     1980      1     5           James Ray        F    Jacksonville
# ...    ...    ...   ...                 ...      ...             ...
# 2161  1990      2    50       MiloÅ¡ BabiÄ‡        C  Tennessee Tech
# 2162  1990      2    51          Tony Smith        G       Marquette
# 2163  1990      2    52     Stefano Rusconi     PF/C   Ranger Varese
# 2164  1990      2    53  Abdul Shamsid-Deen        C      Providence
# 2165  1990      2    54        Sean Higgins      G/F        Michigan
#
#          last name first name
# 0          Carroll  Joe Barry
# 1         Griffith    Darrell
# 2           McHale      Kevin
# ...

# %%
Data3.loc[Data3['school'] == "Ohio State"].head(50)
# Out:
#       year  round  pick                player position      school  \
# 3     1980      1     4         Kelvin Ransey        G  Ohio State
# 59    1981      1    14         Herb Williams      F/C  Ohio State
# 99    1982      1     8         Clark Kellogg       PF  Ohio State
# 176   1983      2    39     Granville Waiters        C  Ohio State
# 204   1984      1    20         Tony Campbell      G/F  Ohio State
# 287   1986      1     9          Brad Sellers        C  Ohio State
# 328   1987      1     3         Dennis Hopson       SF  Ohio State
# 580   1994      2    51  Lawrence Funderburke       PF  Ohio State
# 915   2000      2    43          Michael Redd       SG  Ohio State
# 929   2000      2    57          Scoonie Penn        G  Ohio State
# 979   2001      2    49           Ken Johnson        C  Ohio State
# 1284  2007      1     1             Greg Oden        C  Ohio State
# 1287  2007      1     4           Mike Conley       PG  Ohio State
# ...

# %%
Data3.to_csv("NBADraftData2.csv", index = False)

# %%
# Below, the player lookup csv provided by Nirmal is introduced and used to add the player id column
# This was done to make both an inner merged version and "right" merge.
# The first to provide clean data for upload to the database and the other to retain player data for player names with encoding issues
filepath = "Player_lookup.csv"
player_lookup = pd.read_csv(filepath)
player_lookup
# Out:
#       player_id          player_name first_name    last_name
# 0         23615       Alaa Abdelnaby       Alaa    Abdelnaby
# 1         23616   Mahmoud Abdul-Rauf    Mahmoud   Abdul-Rauf
# 2         23617    Tariq Abdul-Wahad      Tariq  Abdul-Wahad
# 3         23618  Shareef Abdur-Rahim    Shareef  Abdur-Rahim
# 4         23619         Alex Abrines       Alex      Abrines
# ...         ...                  ...        ...          ...
# 2676      26317    Stephen Zimmerman    Stephen    Zimmerman
# 2677      26318          Paul Zipser       Paul       Zipser
# 2678      26319           Ante Zizic       Ante        Zizic
# 2679      26320             Jim Zoet        Jim         Zoet
# 2680      26321          Ivica Zubac      Ivica        Zubac
#
# [2681 rows x 4 columns]

# %%
playerRN = player_lookup.rename({'player_name': 'player'}, axis=1)
playerRN
# Out:
#       player_id               player first_name    last_name
# 0         23615       Alaa Abdelnaby       Alaa    Abdelnaby
# 1         23616   Mahmoud Abdul-Rauf    Mahmoud   Abdul-Rauf
# 2         23617    Tariq Abdul-Wahad      Tariq  Abdul-Wahad
# 3         23618  Shareef Abdur-Rahim    Shareef  Abdur-Rahim
# 4         23619         Alex Abrines       Alex      Abrines
# ...         ...                  ...        ...          ...
# 2676      26317    Stephen Zimmerman    Stephen    Zimmerman
# 2677      26318          Paul Zipser       Paul       Zipser
# 2678      26319           Ante Zizic       Ante        Zizic
# 2679      26320             Jim Zoet        Jim         Zoet
# 2680      26321          Ivica Zubac      Ivica        Zubac
#
# [2681 rows x 4 columns]

# %%
lookupTest = pd.merge(playerRN, Data3, on='player', how='right')
lookupTest
# Out:
#       player_id               player first_name    last_name  year  round  \
# 0        9101.0       Alaa Abdelnaby       Alaa    Abdelnaby  1990      1
# 1        9105.0    Tariq Abdul-Wahad      Tariq  Abdul-Wahad  1997      1
# 2        9106.0  Shareef Abdur-Rahim    Shareef  Abdur-Rahim  1996      1
# 3        9111.0           Alex Acker       Alex        Acker  2005      2
# 4        9113.0           Mark Acres       Mark        Acres  1985      2
# ...         ...                  ...        ...          ...   ...    ...
# 2188        NaN        Chris Jackson        NaN          NaN  1990      1
# 2189        NaN          Toni KukoÄ        NaN          NaN  1990      2
# 2190        NaN       Phil Henderson        NaN          NaN  1990      2
# 2191        NaN        MiloÅ¡ BabiÄ‡        NaN          NaN  1990      2
# 2192        NaN   Abdul Shamsid-Deen        NaN          NaN  1990      2
#
#       pick position          school     last name first name
# ...

# %%
lookupTest = lookupTest.drop(columns=['first_name', 'last_name'])

# %%
lookupTest.to_csv("DraftDataID.csv", index = 'player_id')

# %%
lookupTest2 = pd.merge(playerRN, Data3, on='player', how='inner')
lookupTest2
lookupTest2 = lookupTest2.drop(columns=['first_name', 'last_name'])
lookupTest2 = lookupTest2.rename({'last name': 'last_name', 'first name': 'first_name'}, axis=1)
lookupTest2.to_csv("DraftDataIDClean1.csv", index = False)

# %%
lookupTest2
# Out:
#       player_id               player  year  round  pick position  \
# 0         23615       Alaa Abdelnaby  1990      1    25       PF
# 1         23617    Tariq Abdul-Wahad  1997      1    11       SF
# 2         23618  Shareef Abdur-Rahim  1996      1     3        F
# 3         23620           Alex Acker  2005      2    60        G
# 4         23621           Mark Acres  1985      2    40      F/C
# ...         ...                  ...   ...    ...   ...      ...
# 1636      26315         George Zidek  1995      1    22        C
# 1637      26316    Derrick Zimmerman  2003      2    40       PG
# 1638      26317    Stephen Zimmerman  2016      2    41     PF/C
# 1639      26318          Paul Zipser  2016      2    48    SG/SF
# 1640      26321          Ivica Zubac  2016      2    32        C
#
#                  school    last_name first_name
# 0                  Duke    Abdelnaby       Alaa
# 1        San Jose State  Abdul-Wahad      Tariq
# ...

# %%
lookupTest
# Out:
#       player_id               player  year  round  pick position  \
# 0        9101.0       Alaa Abdelnaby  1990      1    25       PF
# 1        9105.0    Tariq Abdul-Wahad  1997      1    11       SF
# 2        9106.0  Shareef Abdur-Rahim  1996      1     3        F
# 3        9111.0           Alex Acker  2005      2    60        G
# 4        9113.0           Mark Acres  1985      2    40      F/C
# ...         ...                  ...   ...    ...   ...      ...
# 2188        NaN        Chris Jackson  1990      1     3       PG
# 2189        NaN          Toni KukoÄ  1990      2    29       SF
# 2190        NaN       Phil Henderson  1990      2    49       SG
# 2191        NaN        MiloÅ¡ BabiÄ‡  1990      2    50        C
# 2192        NaN   Abdul Shamsid-Deen  1990      2    53        C
#
#               school     last name first name
# 0               Duke     Abdelnaby       Alaa
# 1     San Jose State   Abdul-Wahad      Tariq
# ...

# %%
# Clean and merge season stats csv with player lookup
filepath = "Seasons_Stats.csv"
SeasonData = pd.read_csv(filepath)
SeasonData = SeasonData.drop(columns=['Unnamed: 0'])
SeasonData
# Out:
#          Year             Player  Pos   Age   Tm     G    GS      MP   PER  \
# 0      1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN     NaN   NaN
# 1      1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN     NaN   NaN
# 2      1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN     NaN   NaN
# 3      1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN     NaN   NaN
# 4      1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN     NaN   NaN
# ...       ...                ...  ...   ...  ...   ...   ...     ...   ...
# 24686  2017.0        Cody Zeller   PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller    C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser   SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac    C  19.0  LAL  38.0  11.0   609.0  17.0
#
# ...

# %%
SeasonData = SeasonData.dropna(how='all')
SeasonData = SeasonData.rename({'Player':'player'}, axis=1)
SeasonDataID = pd.merge(playerRN, SeasonData, on='player', how='inner')
SeasonDataID = SeasonDataID.drop(columns=['first_name', 'last_name',])

# %%
SeasonDataID
# Out:
#        player_id             player    Year Pos   Age   Tm     G    GS  \
# 0          23615     Alaa Abdelnaby  1991.0  PF  22.0  POR  43.0   0.0
# 1          23615     Alaa Abdelnaby  1992.0  PF  23.0  POR  71.0   1.0
# 2          23615     Alaa Abdelnaby  1993.0  PF  24.0  TOT  75.0  52.0
# 3          23615     Alaa Abdelnaby  1993.0  PF  24.0  MIL  12.0   0.0
# 4          23615     Alaa Abdelnaby  1993.0  PF  24.0  BOS  63.0  52.0
# ...          ...                ...     ...  ..   ...  ...   ...   ...
# 16996      26316  Derrick Zimmerman  2006.0  PG  24.0  NJN   2.0   0.0
# 16997      26317  Stephen Zimmerman  2017.0   C  20.0  ORL  19.0   0.0
# 16998      26318        Paul Zipser  2017.0  SF  22.0  CHI  44.0  18.0
# 16999      26320           Jim Zoet  1983.0   C  29.0  DET   7.0   0.0
# 17000      26321        Ivica Zubac  2017.0   C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB   AST   STL   BLK   TOV  \
# ...

# %%
SeasonDataID.dtypes
# Out:
# player_id      int64
# player        object
# Year         float64
# Pos           object
# Age          float64
# Tm            object
# G            float64
# GS           float64
# MP           float64
# PER          float64
# TS%          float64
# 3PAr         float64
# FTr          float64
# ORB%         float64
# DRB%         float64
# TRB%         float64
# AST%         float64
# STL%         float64
# BLK%         float64
# TOV%         float64
# USG%         float64
# blanl        float64
# OWS          float64
# DWS          float64
# WS           float64
# WS/48        float64
# blank2       float64
# OBPM         float64
# DBPM         float64
# BPM          float64
# VORP         float64
# FG           float64
# FGA          float64
# FG%          float64
# 3P           float64
# 3PA          float64
# 3P%          float64
# 2P           float64
# 2PA          float64
# 2P%          float64
# eFG%         float64
# FT           float64
# FTA          float64
# ...

# %%
SeasonDataID.to_csv("Seasons_StatsClean.csv", index = False)
